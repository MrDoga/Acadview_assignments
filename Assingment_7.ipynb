# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/MrDoga/Acadview_assignments/blob/master/Assingment_7.ipynb)

# %%
#Q1 Import the dataset and write a description about the dataset.
from google.colab import files
files.upload()

#This dataset is made by us government. It depicts different countries along with different states and there population. It also tell us about the gdp,literacy rate ,climate,agriculture etc about that particular country
# Out:
#      <input type="file" id="files-80426c2f-34dd-4bf4-94c8-ba93e9277045" name="files[]" multiple disabled />
#      <output id="result-80426c2f-34dd-4bf4-94c8-ba93e9277045">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving countries of the world.csv to countries of the world.csv
# ...

# %%
import pandas as pd 
c=pd.read_csv("countries of the world.csv")
c.head(5)
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
c.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
#Q2. Find the count of the missing values and describe how you have handled the missing data.
m=c.dropna()
m
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# 11              Australia   OCEANIA                                20264082
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# ...

# %%
pd.crosstab(c['Population'],c['Region'],margins=True)
# Out:
# Region      ASIA (EX. NEAR EAST)           \
# Population
# 7026                                    0
# 7502                                    0
# 9439                                    0
# 11810                                   0
# 13287                                   0
# 13477                                   0
# 16025                                   0
# 20579                                   0
# 21152                                   0
# 21388                                   0
# 23098                                   0
# 27928                                   0
# 29251                                   0
# 32543                                   0
# 33987                                   0
# 39129                                   0
# 45436                                   0
# 47246                                   0
# 56361                                   0
# 57794                                   0
# 60422                                   0
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.rcParams['figure.figsize']=(8,6)
sns.countplot(x='Country',hue='Service',data='c')
